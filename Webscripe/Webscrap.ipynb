# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests,re,lxml
from bs4 import BeautifulSoup
import pandas as pd
import time
import os

# %%
project_dir = '/content/drive/MyDrive/Blackcoffer/Data'

dir_path = os.path.join(project_dir)
if not os.path.exists(project_dir):
   os.makedirs(dir_path)
   print(f"Created directory: {dir_path}")
else:
   print(f"Directory already exists: {dir_path}")
# Out:
# Directory already exists: /content/drive/MyDrive/Blackcoffer/Data

# %%
df = pd.read_excel("/content/Input.xlsx")
df
# Out:
#              URL_ID                                                URL
# 0   blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1   blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2   blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3   blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4   blackassign0005  https://insights.blackcoffer.com/ott-platform-...
# ..              ...                                                ...
# 95  blackassign0096  https://insights.blackcoffer.com/what-is-the-r...
# 96  blackassign0097  https://insights.blackcoffer.com/impact-of-cov...
# 97  blackassign0098  https://insights.blackcoffer.com/contribution-...
# 98  blackassign0099  https://insights.blackcoffer.com/how-covid-19-...
# 99  blackassign0100  https://insights.blackcoffer.com/how-will-covi...
#
# [100 rows x 2 columns]

# %%
def extract_article_data(url):
    static_data_count = 0  # Counter for data points within this function

    def fetch_and_process_data():
        nonlocal static_data_count  # Access the outer counter

        response = requests.get(url)
        soup = BeautifulSoup(response.content, "lxml")

        # Find the article title and content elements
        title = soup.find("h1", class_="entry-title")
        content = soup.find("div", class_="td-post-content tagdiv-type")

        # Remove unwanted content within <pre> tag
        unwanted_content = content.find("pre", class_="wp-block-preformatted")
        if unwanted_content:
            unwanted_content.decompose()

        if title and content:
            article_title = title.text.strip()
            article_text = content.get_text(separator='\n').strip()
            return article_title, article_text
        else:
            return None, None

    while True:  # Loop until data is successfully fetched
        result = fetch_and_process_data()
        if result is not None:
            return result

        static_data_count += 1
        if static_data_count % 5 == 0:  # Check for time lapse
            print("Pausing for 5 seconds within extract_article_data...")
            time.sleep(5)

# %%
for index, row in df.iterrows():
    url_id = row["URL_ID"]
    url = row["URL"]
    try:
        article_title, article_text = extract_article_data(url)

        if article_title and article_text:
            file_path = os.path.join(project_dir, f"{url_id}.txt")  # Construct full file path
            with open(file_path, "w", encoding="utf-8") as f:
                f.write(article_title + "\n\n")
                f.write(article_text)
            print(f"Data saved to: {file_path}")
        else:
            print(f"Extraction failed for URL: {url}")

    except:
        print(f"Extraction failed for URL: {url}")
# Out:
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0001.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0002.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0003.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0004.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0005.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0006.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0007.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0008.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0009.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0010.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0011.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0012.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0013.txt
# Extraction failed for URL: https://insights.blackcoffer.com/rise-of-e-health-and-its-imapct-on-humans-by-the-year-2030-2/
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0015.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0016.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0017.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0018.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0019.txt
# Extraction failed for URL: https://insights.blackcoffer.com/how-advertisement-increase-your-market-value/
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0021.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0022.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0023.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0024.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0025.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0026.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0027.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0028.txt
# Extraction failed for URL: https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0030.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0031.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0032.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0033.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0034.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0035.txt
# Extraction failed for URL: https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0037.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0038.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0039.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0040.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0041.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0042.txt
# Extraction failed for URL: https://insights.blackcoffer.com/future-of-work-how-ai-has-entered-the-workplace/
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0044.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0045.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0046.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0047.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0048.txt
# Extraction failed for URL: https://insights.blackcoffer.com/covid-19-environmental-impact-for-the-future/
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0050.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0051.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0052.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0053.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0054.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0055.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0056.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0057.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0058.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0059.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0060.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0061.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0062.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0063.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0064.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0065.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0066.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0067.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0068.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0069.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0070.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0071.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0072.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0073.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0074.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0075.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0076.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0077.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0078.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0079.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0080.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0081.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0082.txt
# Extraction failed for URL: https://insights.blackcoffer.com/human-rights-outlook/
# Extraction failed for URL: https://insights.blackcoffer.com/how-voice-search-makes-your-business-a-successful-business/
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0085.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0086.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0087.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0088.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0089.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0090.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0091.txt
# Extraction failed for URL: https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work-3/
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0093.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0094.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0095.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0096.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0097.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0098.txt
# Extraction failed for URL: https://insights.blackcoffer.com/how-covid-19-is-impacting-payment-preferences/
# Extraction failed for URL: https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-2/

# %%
## I checked Manually , I found ther is some article not scrapped {14,10,29,36,43,49,83,84,92,99,100}
## reason there class are different
unscraped_url_ID = [
    "blackassign0014",
    "blackassign0020",
    "blackassign0029",
    "blackassign0036",
    "blackassign0043",
    "blackassign0049",
    "blackassign0083",
    "blackassign0084",
    "blackassign0092",
    "blackassign0099",
    "blackassign0100",
]

# %%
headers = {
    'authority': 'insights.blackcoffer.com',
    'method': 'GET',
    'scheme': 'https',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-GB,en-US;q=0.9,en;q=0.8,or;q=0.7,hi;q=0.6',
    'Cache-Control': 'max-age=0',
    'Referer': 'https://colab.research.google.com/',
    'Sec-Ch-Ua': '"Not_A Brand";v="8", "Chromium";v="120", "Google Chrome";v="120"',
    'Sec-Ch-Ua-Mobile': '?0',
    'Sec-Ch-Ua-Platform': '"Windows"',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'cross-site',
    'Sec-Fetch-User': '?1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
}

# %%
def extract_article_data1(url):
    static_data_count = 0  # Counter for data points within this function

    def fetch_and_process_data():
        nonlocal static_data_count  # Access the outer counter

        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, "lxml")

        # Find the article title and content elements
        title = soup.find("h1", class_="tdb-title-text")
        text = soup.findAll("div", class_="tdb-block-inner td-fix-index")
        # Remove unwanted content within <pre> tag
        unwanted_content = text.find("pre", class_="wp-block-preformatted")
        if unwanted_content:
            unwanted_content.decompose()


        if title and text:
            article_title = title.text.strip()
            html_content = ''.join(str(tag) for tag in text)
            soup_1 = BeautifulSoup(html_content, 'html.parser')
            paragraphs = soup_1.find_all('p')
            article_text = '\n'.join(paragraph.get_text(strip=True) for paragraph in paragraphs)
            return article_title, article_text
        else:
            return None, None

    while True:  # Loop until data is successfully fetched
        result = fetch_and_process_data()
        if result is not None:
            return result

        static_data_count += 1
        if static_data_count % 5 == 0:  # Check for time lapse
            print("Pausing for 4 seconds within extract_article_data...")
            time.sleep(4)

# %%
for index, row in df.iterrows():
    url_id = row["URL_ID"]
    if url_id in unscraped_url_ID:
        url = row["URL"]  # Retrieve the actual URL
        try:
            article_title, article_text = extract_article_data1(url)  # Pass the URL directly
            if article_title and article_text:
                file_path = os.path.join(project_dir, f"{url_id}.txt")
                with open(file_path, "w", encoding="utf-8") as f:
                    f.write(article_title + "\n\n")
                    f.write(str(article_text))
                print(f"Data saved to: {file_path}")
            else:
                print(f"Extraction failed for URL: {url}")
        except:
            print(f"Extraction failed for URL: {url}")



 ####   I checked manually 36 and 49 url  is not opening.
# Out:
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0014.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0020.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0029.txt
# Extraction failed for URL: https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0043.txt
# Extraction failed for URL: https://insights.blackcoffer.com/covid-19-environmental-impact-for-the-future/
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0083.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0084.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0092.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0099.txt
# Data saved to: /content/drive/MyDrive/Blackcoffer/Data/blackassign0100.txt
